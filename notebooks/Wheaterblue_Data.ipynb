# %%
pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 KB 4.7 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Paso 1: Cargar el conjunto de datos
df = pd.read_csv('dataexport_20240515T194154.csv', skiprows=9)  

# Drop rows with NaN values
df_cleaned = df.dropna()

#print(df)

# %%
df_without_metadata = df_cleaned

# %%
# Paso 2: Exploración de datos sin las primeras 9 filas
print("Estructura del conjunto de datos:")
print(df_without_metadata.info())

print("\nPrimeras filas del conjunto de datos:")
print(df_without_metadata.head())

# Estadísticas descriptivas básicas
print("\nEstadísticas descriptivas:")
print(df_without_metadata.describe())

print(df.head())


# Visualización de la distribución de variables numéricas
#sns.pairplot(df_without_metadata)  # Gráficos de dispersión para variables numéricas
#plt.show()
# Out:
# Estructura del conjunto de datos:
# <class 'pandas.core.frame.DataFrame'>
# Index: 739395 entries, 7 to 739415
# Data columns (total 8 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   timestamp                                    739395 non-null  object
#  1   Basel Temperature [2 m elevation corrected]  739395 non-null  float64
#  2   Basel Precipitation Total                    739395 non-null  float64
#  3   Basel Wind Gust                              739395 non-null  float64
#  4   Basel Cloud Cover Total                      739395 non-null  float64
#  5   Basel Sunshine Duration                      739395 non-null  float64
#  6   Basel Mean Sea Level Pressure [MSL]          739395 non-null  float64
#  7   Basel Evapotranspiration                     739395 non-null  float64
# dtypes: float64(7), object(1)
# memory usage: 50.8+ MB
# None
#
# ...

# %%
# Mapas de calor de correlación
df_without_timestamp = df_without_metadata.drop(columns=[df_without_metadata.columns[0]])
corr_matrix = df_without_timestamp.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Mapa de calor de correlación')
plt.show()

# Paso adicional: Mostrar las primeras 9 filas como datos
print("\nPrimeras 9 filas del conjunto de datos (incluyendo metadatos):")
df_with_metadata = pd.read_csv('dataexport_20240515T194154.csv', nrows=8)  # Cargar solo las primeras 9 filas
print(df_with_metadata)
# Out:
# Primeras 9 filas del conjunto de datos (incluyendo metadatos):
#       location                    Basel              Basel.1    Basel.2  \
# 0          lat                 47.75000             47.75000   47.75000
# 1          lon                  7.50000              7.50000    7.50000
# 2          asl                  363.653              363.653    363.653
# 3     variable              Temperature  Precipitation Total  Wind Gust
# 4         unit                       °C                   mm       km/h
# 5        level  2 m elevation corrected                  sfc        sfc
# 6   resolution                   hourly               hourly     hourly
# 7  aggregation                      NaN                  NaN        NaN
#
#              Basel.3            Basel.4                  Basel.5  \
# 0           47.75000           47.75000                 47.75000
# 1            7.50000            7.50000                  7.50000
# ...
